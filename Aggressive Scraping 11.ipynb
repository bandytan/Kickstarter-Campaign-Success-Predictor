# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import os 
import ast
import json
import time
from requests.exceptions import ConnectionError

# %% [markdown]
# https://stackoverflow.com/questions/62335537/scraping-text-from-kickstarter-projects-return-nothing

# %%
base = "/Users/ivankoh/Downloads/kickstarter data/"
filepaths = [base + f for f in os.listdir(base) if f.endswith('.csv')]
df = pd.concat(map(pd.read_csv, filepaths))
df_1 = df.drop_duplicates(subset=['id'])
df_1['main_url'] = df_1['urls'].apply(lambda x: eval(x)['web']['project'])
print(len(df))
print(len(df_1))
# Out:
# 392244
# 203510
# /var/folders/dq/33rpc0cx4f54t0vx2cdcgczr0000gn/T/ipykernel_42489/4110031066.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['main_url'] = df_1['urls'].apply(lambda x: eval(x)['web']['project'])

# %%
def get_slug(url):
    return re.search('/projects/(.*)\?', url).group(1)

# get the slug from the urls. the slug is the input to the GraphQL API call 
slugs = list(map(get_slug, df_1['main_url'].tolist()))
# while iterating through all projects, add the story and risk to these lists. At the end len of both list 
# should be the same as the len of the dataframe. if all good then add as columns to the dataframe df. 
creator_list = []

# %%
# instantiate a new Session 
s = requests.Session()

query = """
query Campaign($slug: String!) {
  project(slug: $slug) {
    risks
    story(assetWidth: 680)
  }
}"""

# PARAMS
counter = 0
# pause for 30 seconds every 5 iterations
for i in range(2705, 3000):
    slug = slugs[i]
    if counter == 5:
        print("TAKING A NAP ZZZ...")
        time.sleep(30)
        counter = 0
    counter += 1
    print(f"--------{slug}------")
    # POST request to GraphQL API situated in kickstarter domain 
    # response from POST request should contain the story and risks
    connect_try = 0
    not_found = True
    while connect_try < 30 and not_found:       
        try:
            r = s.post("https://www.kickstarter.com/graph",
                headers = {
                  'content-type': 'application/json',
                  'x-csrf-token': 'bL5nMRm5s147N8RxvNcth-E8NAOt3SprGYtvvKsVLnuZ3XwQ71cy1zrDfjIAGTCHV0obMRNqRMbBJT7nF2ZSAA',
                  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
                  'cookie': '_ksr_session=eus10UNK7iB%2FwIMXafXg5yJdYvRD7rHlR%2Ba1KEbUnB5EKTgQxNKEIqrp%2BIyjRC%2FNXw76u4Eki4AsiBom5M1LKNJKWCD65CBzeegWrk2%2FRV9Sht6dlOKplCATNdrmEIIa0Bt%2FKKGnT2m9ID1nTCduj73%2BdeJK663MNcbYWXBHkFyZJgUKh4JcCx3hL0UF2quVeBvfV45M0CNrT1j4DchvTlFBn%2BpE37ZaGldNz7BF0RAcCjIZrt%2FzNkxugCaFfWEPjxh9amOCvytIcdjxOaE68AAmHuU%3D--RPNmoWC%2FGnWTmsfw--9466UG%2Bqs2V%2F8B8zFtXUig%3D%3D'
                },
                json = {
                    "variables":{
                        "slug": slug
                    },
                    "query": "query CreatorSection($slug: String!) {\n  me {\n    id\n    name\n  }\n  project(slug: $slug) {\n    id\n    verifiedIdentity\n    creator {\n      id\n      name\n      imageUrl(width: 100)\n      url\n      lastLogin\n      biography\n      isFacebookConnected\n      allowsFollows\n      backingsCount\n      location {\n        displayableName\n      }\n      launchedProjects {\n        totalCount\n      }\n      websites {\n        url\n        domain\n      }\n    }\n    collaborators {\n      edges {\n        node {\n          name\n          imageUrl(width: 200)\n          url\n        }\n        title\n      }\n    }\n  }\n}\n"
                })
            not_found = False
        except ConnectionError:
            print("Connection Error")
            time.sleep(5)
            connect_try += 1
    try:
        result = r.json()
        print("-----CREATOR-----")
        creator_list.append(result['data']['project'])
    except:
        print(r)
        print("TAKING A BIG NAP ZZZ...")
        time.sleep(60*30)
        #try one more time
        r = s.post("https://www.kickstarter.com/graph",
                headers = {
                  'content-type': 'application/json',
                  'x-csrf-token': 'bL5nMRm5s147N8RxvNcth-E8NAOt3SprGYtvvKsVLnuZ3XwQ71cy1zrDfjIAGTCHV0obMRNqRMbBJT7nF2ZSAA',
                  'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:50.0) Gecko/20100101 Firefox/50.0',
                  'cookie': '_ksr_session=eus10UNK7iB%2FwIMXafXg5yJdYvRD7rHlR%2Ba1KEbUnB5EKTgQxNKEIqrp%2BIyjRC%2FNXw76u4Eki4AsiBom5M1LKNJKWCD65CBzeegWrk2%2FRV9Sht6dlOKplCATNdrmEIIa0Bt%2FKKGnT2m9ID1nTCduj73%2BdeJK663MNcbYWXBHkFyZJgUKh4JcCx3hL0UF2quVeBvfV45M0CNrT1j4DchvTlFBn%2BpE37ZaGldNz7BF0RAcCjIZrt%2FzNkxugCaFfWEPjxh9amOCvytIcdjxOaE68AAmHuU%3D--RPNmoWC%2FGnWTmsfw--9466UG%2Bqs2V%2F8B8zFtXUig%3D%3D'
                },
                json = {
                    "variables":{
                        "slug": slug
                    },
                    "query": "query CreatorSection($slug: String!) {\n  me {\n    id\n    name\n  }\n  project(slug: $slug) {\n    id\n    verifiedIdentity\n    creator {\n      id\n      name\n      imageUrl(width: 100)\n      url\n      lastLogin\n      biography\n      isFacebookConnected\n      allowsFollows\n      backingsCount\n      location {\n        displayableName\n      }\n      launchedProjects {\n        totalCount\n      }\n      websites {\n        url\n        domain\n      }\n    }\n    collaborators {\n      edges {\n        node {\n          name\n          imageUrl(width: 200)\n          url\n        }\n        title\n      }\n    }\n  }\n}\n"
                })
        try:
            result = r.json()
            print("-----CREATOR-----")
            creator_list.append(result['data']['project'])
        except:
            print("NAP DIDN't WORK", r)
            break
# Out:
# --------petgroominggloves/relaunch-hicc-groomtm-safe-powerful-pet-grooming-gloves------
# <Response [429]>
# TAKING A BIG NAP ZZZ...
# -----CREATOR-----
# --------alanbackpack101/vesty-unique-minimal-messenger-bag-sling-bag-commute-day-bag------
# -----CREATOR-----
# --------liefwafel/liefwafel-waffle-company-authentic-liege-waffle-concession------
# -----CREATOR-----
# --------pasiontacos/pasion-tacos-food-truck-a-new-luxury-taco-experience------
# -----CREATOR-----
# --------iamentertainmentmag/i-am-entertainment-national-newsstand-launch------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------989925720/retro-gaming-magazine------
# -----CREATOR-----
# --------snactiv/snactiv------
# -----CREATOR-----
# --------examask/exa-mask------
# -----CREATOR-----
# --------beauxbeau/mooncore-pin-series------
# -----CREATOR-----
# --------paladinpie/paladin-pie-the-food-cart------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------hbaumann/bloom-burger-a-food-truck-for-american-flavors------
# -----CREATOR-----
# --------jennyloughmiller/jenny-maries-bringing-gelati-to-oregon------
# -----CREATOR-----
# --------549312583/liminal-journal-of-green-anarchy-issues-5-and-6------
# -----CREATOR-----
# --------1698576947/the-ukulele-magazine------
# -----CREATOR-----
# --------threetinycats/gourmet-cats------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------haatonokoe/animals-are-the-best-goodies-new-designs------
# -----CREATOR-----
# --------w-t/foreverpen-writing-without-limits------
# -----CREATOR-----
# --------rocketbook/axis-notebook------
# -----CREATOR-----
# --------1184414626/opening-the-eyes-of-the-world------
# -----CREATOR-----
# --------254690870/on-the-inside-the-new-album-by-wilson-bunton------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------250862761/changing-the-way-college-students-process-informat------
# -----CREATOR-----
# --------1166823094/nothin-less-neighborhood-newspaper------
# -----CREATOR-----
# --------73908031/heads-up-will-we-stop-making-cents------
# -----CREATOR-----
# --------serytama/mythical-creatures-enamel-pins------
# -----CREATOR-----
# --------etherealnight/dripping-with-pride------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------1976439142/r-tronika-in-mexico------
# -----CREATOR-----
# --------525280761/dreaming-of-now-features-musical-legends-and-invit------
# -----CREATOR-----
# --------bjmorton/dallas-writers-journal------
# -----CREATOR-----
# --------1356242277/kill-pretty-magazine-issue-2------
# -----CREATOR-----
# --------beepositive/isolation-vacation-enamel-pins-and-stationery-by-liz-harry------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------cookiecooper/truckin-along-with-t-rex-cookie------
# -----CREATOR-----
# --------358159594/revolution-tour-to-china------
# -----CREATOR-----
# --------2038141080/wet-city-rockers-need-you------
# -----CREATOR-----
# --------1937828839/asamaan-festival-of-music-and-astronomy------
# -----CREATOR-----
# --------1362226663/disposable-addiction------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------strayaobscura/worldwide-dragons-enamel-pins------
# -----CREATOR-----
# --------jemaica/jemaicas-fantasy-art-coloring-book-2020------
# -----CREATOR-----
# --------70427218/mania-africa-exploring-african-lifestyle-and-cultu------
# -----CREATOR-----
# --------398554831/b-boys-first-single-slam------
# -----CREATOR-----
# --------studiounderd0g/a-playful-mechanical-chronograph-st-1901-studio-underd0g------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------carlypifer/aurore-erotica-updated------
# -----CREATOR-----
# --------musicbyangela/my-first-solo-album-1------
# -----CREATOR-----
# --------hellobayart/magical-familiars-enamel-pins------
# -----CREATOR-----
# --------lune-awa/bnha-wonderland-stickers-and-keychains-0------
# -----CREATOR-----
# --------113740614/the-mortise-range-make-a-stand------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------elladesigns/3-hard-enamel-keyrings------
# -----CREATOR-----
# --------mahogonymagazine/mahogony-magazine-launch------
# -----CREATOR-----
# --------1151382680/michelle-gold-is-recording-a-brand-new-music-proje------
# -----CREATOR-----
# --------971280569/december-tango-night-live-music-alternative-milong------
# -----CREATOR-----
# --------759369577/omar-lopezs-stringphoenix-in-concert-live-for-dvd------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------carltonreid/virtual-velo-city------
# -----CREATOR-----
# --------mediadiversified/media-diversified-funding-a-new-era-of-writers-of------
# -----CREATOR-----
# --------62909390/subete-al-ring-del-periodismo-libre------
# -----CREATOR-----
# --------1492344371/pressenza-ipa------
# -----CREATOR-----
# --------rivernews/the-river-a-community-newsroom------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------nickwallis/reporting-the-high-court-post-office-trial------
# -----CREATOR-----
# --------826593979/goody-goody-gumbo-austins-yummiest-gumbo-trailer------
# -----CREATOR-----
# --------thepsalmsprojectco/the-psalms-project-journals------
# -----CREATOR-----
# --------1123274045/inquisition-of-darkness------
# -----CREATOR-----
# --------wakeupthegiant/the-unconditional-a-documentary-film------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------544623986/bringing-neighborhood-news-back-by-block-club-chic------
# -----CREATOR-----
# --------373135845/are-we-europe-best-of-2017------
# -----CREATOR-----
# --------1925490150/evergreen-girls-support-women-in-the-outdoors------
# -----CREATOR-----
# --------trinketandvine/chuubys-tribute-to-essential-guardians------
# -----CREATOR-----
# --------nuahs/happiest-hippo-enamel-pin------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------hamimosmallthings/carl-and-ellie-fredrickson-by-hamimo-small-things------
# -----CREATOR-----
# --------peachypins/brutally-honest-hard-enamel-pins------
# -----CREATOR-----
# --------939963895/my-art-belongs-to-dad-album-and-music-video------
# -----CREATOR-----
# --------26384799/experience-the-uniquely-original-sounds-of-david-a------
# -----CREATOR-----
# --------2004993216/agneta-a-documentary-film------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------1546334867/new-age-magazine-the-next-step-in-gaming-and-tech------
# -----CREATOR-----
# --------1189448240/business-and-entrepreneurship-news-you-care-about------
# -----CREATOR-----
# --------476999561/get-eme-and-heteru-to-live-peace-festival-woodstoc------
# -----CREATOR-----
# --------1062790469/vegas-street-musicians-summer-2012-cd-dvd------
# -----CREATOR-----
# --------zootility-health/comfort-mask-a-unique-twist-on-soft-and-safe-face-masks------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------725739257/greek-street------
# -----CREATOR-----
# --------34630694/where-tradition-meets-modernity-a-global-music-exp------
# -----CREATOR-----
# --------597740212/adventures-and-outings-documentary------
# -----CREATOR-----
# --------278369849/a-thousand-thoughts------
# -----CREATOR-----
# --------pjaccetturo/the-underground-story-awaken-your-calling------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------1431263539/the-white-side------
# -----CREATOR-----
# --------145547642/shady-dawgs------
# -----CREATOR-----
# --------morganngicquel/the-scrooge-mystery-a-feature-duckumentary------
# -----CREATOR-----
# --------lookingforleia/looking-for-leia------
# -----CREATOR-----
# --------2005695073/shortcuts-to-infinity-the-poetry-of-stephen-kalini------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------2073308524/bark-and-the-bite------
# -----CREATOR-----
# --------1500838258/grindhouse-cafe-coffee-and-food-truck-in-nwi------
# -----CREATOR-----
# --------1004938092/quickstarter-eclipse------
# -----CREATOR-----
# --------meisterstein/minoa-the-new-bauhaus-inspired-watch-by-meisterstein-0------
# -----CREATOR-----
# --------118555264/teen-print------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------bitandgrain/bit-and-grain-the-future-of-north-carolina-journal------
# -----CREATOR-----
# --------740427358/hagafu-home-of-awesome------
# -----CREATOR-----
# --------695573380/chai-guys-tea-cart------
# -----CREATOR-----
# --------1185086592/faithful-a-lesbian-mormon-story------
# -----CREATOR-----
# --------1404267082/duty-free-a-documentary-film------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------septemstudio/septem-pure-titanium-camp-grill-and-hotplate------
# -----CREATOR-----
# --------dimillez/xavier-album-titled-i-got-this-hip-hops-hot-new-fa------
# -----CREATOR-----
# --------livsndesigns/ecotrek-adventure-pants-made-from-ocean-buoys------
# -----CREATOR-----
# --------norbertelliottii/ethereal-skateboards------
# -----CREATOR-----
# --------859053242/obviouslies-debut-lp-pinky-vinyl-edition------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------thunder/native-american-flute-cd------
# -----CREATOR-----
# --------heatherhiscox/no-more-status-quo-a-book-for-frustrated-changemakers------
# -----CREATOR-----
# --------hopesanddreamsof100/the-hopes-and-dream-of-100-lives------
# -----CREATOR-----
# --------thewhitewitchoracle/the-witchs-familiar-runic-oracle------
# -----CREATOR-----
# --------fearlesslynaira/the-digital-revolution-a-social-rebellion------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------wilfernandez/vintage-2015-a-year-in-american-wine------
# -----CREATOR-----
# --------professorbuzzkill/professor-buzzkill------
# -----CREATOR-----
# --------1931255568/international-policy-digest------
# -----CREATOR-----
# --------289578670/tru-pizza-truck------
# -----CREATOR-----
# --------plasticinvasion/scale-modeling-ww2------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------697656125/sos-the-salton-sea-walk-film------
# -----CREATOR-----
# --------2101354192/living-across-the-rainforests------
# -----CREATOR-----
# --------fugutruck/fugu-food-truck-authentic-asian-street-food-on-whe------
# -----CREATOR-----
# --------1512480726/vitality-fresh-fast-food-truck------
# -----CREATOR-----
# --------peterwiebe/libera-lebensmittel-bis-vor-die-haustur------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------708969873/civil-eats-food-policy-news-and-commentary-with-bi------
# -----CREATOR-----
# --------gotoplanb/for-journalism------
# -----CREATOR-----
# --------readmatter/matter------
# -----CREATOR-----
# --------ayvi-mag/ay-vi-magazine------
# -----CREATOR-----
# --------312682680/hans-arnold-dokumentaren-om-penselns-haxmastare------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------kevinplueard/operation-potato------
# -----CREATOR-----
# --------theslidequeen/the-slide-queen-food-truck------
# -----CREATOR-----
# --------maine200cookbook/volume2------
# -----CREATOR-----
# --------minervamonster/the-mothman-of-point-pleasant-and-invasion-on-ches------
# -----CREATOR-----
# --------hollerin/caviar-dreams-the-most-decadent-food-doc-ever-made------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------1897260347/high-water-film------
# -----CREATOR-----
# --------zoeg/make-it-green------
# -----CREATOR-----
# --------707800115/surraeon-a-sci-fi-concept-album------
# -----CREATOR-----
# --------thecurb/the-australian-film-yearbook-2021-edition------
# -----CREATOR-----
# --------wendell-britt/mastering-the-game-of-allyship------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------tacorevolution/the-next-evolution-of-taco-revolution-a-taco-truck------
# -----CREATOR-----
# --------1028909096/lets-get-that-difficult-3rd-album-out-there------
# -----CREATOR-----
# --------contraphonic/contraphonic-sound-series-map-your-city------
# -----CREATOR-----
# --------nataliehammerquist/a-visual-guide-to-foraging-medicinal-plants-in-the-pnw------
# -----CREATOR-----
# --------oregonsports/oregonsports-programming-network-mobile-app------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------lepagenovembre/the-tarot-of-devotion-second-edition------
# -----CREATOR-----
# --------pierangeloboog/sphinx-art-book-pierangelo-boog------
# -----CREATOR-----
# --------tanuan/light-codes------
# -----CREATOR-----
# --------withkiya/building-soup-a-manual-with-recipes-and-techniques------
# -----CREATOR-----
# --------2058794779/wake-up-into-my-love-a-book-by-carson-leith------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------kateshaw/beyond-bigfoot-and-nessie------
# -----CREATOR-----
# --------frankwkelly/8-simple-steps-to-making-your-short-film------
# -----CREATOR-----
# --------danielhoffman/push-otherwise-its-just-firewood-over-the-top-for------
# -----CREATOR-----
# --------inksplosion7/inksplosion-volume-9------
# -----CREATOR-----
# --------badassblue/make-100-badass-blue------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------sylk/sylk-magazine-project-for-young-women------
# -----CREATOR-----
# --------grahamgiller/a-survey-of-current-consumer-conditions-and-expectations------
# -----CREATOR-----
# --------evanhgregg/dear-mister-ward-complaint-letters-from-the-1930s------
# -----CREATOR-----
# --------kairui/usapuri-2019-artbook------
# -----CREATOR-----
# --------730497413/make-100amphibians-and-reptiles-you-will-never-see-again------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------theboatdog20/the-boat-dog------
# -----CREATOR-----
# --------shereesbook/a-mothers-strength-and-resilience------
# -----CREATOR-----
# --------952726622/green-school-stories-a-film-to-inspire-change-in-e------
# -----CREATOR-----
# --------510654858/wahl-kompass-zur-landtagswahl-thuringen-2019------
# -----CREATOR-----
# --------lost-in-cult/lock-on-volume-002-a-gaming-journal------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------hackthegap/hack-the-gap-book------
# -----CREATOR-----
# --------crystalrenaud/dirty-girls-renewed-by-crystal-renaud-day------
# -----CREATOR-----
# --------1596167206/nemesis-known-a-boss-monster-zine------
# -----CREATOR-----
# --------1975207410/look-at-me-now-a-documentary-about-working-moms------
# -----CREATOR-----
# --------macdaddysmac/road-to-mac-daddys-mac------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------683603913/food-trucks-selling-what-others-wont------
# -----CREATOR-----
# --------themuffinfreak/the-muffin-freak------
# -----CREATOR-----
# --------eljefe13goodvibes/chef-q-and-el-jefe-13-presents-good-vibes-food-trailer------
# -----CREATOR-----
# --------meetthehelpers/meet-the-helpers-an-uplifting-speakers-series------
# -----CREATOR-----
# --------kiasherria/celestial-cats------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------tripleebbq/triple-e-bbq------
# -----CREATOR-----
# --------douglasbranson/have-you-seen-tan-documentary-film------
# -----CREATOR-----
# --------1106664908/i-ciclo-de-conferencias-camiseta-espanola------
# -----CREATOR-----
# --------nickys/nickys-pizza------
# -----CREATOR-----
# --------2016281736/softserv------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------crazybox/the-crazy-box-bakery-food-truck------
# -----CREATOR-----
# --------1866709861/color-shifting-word-name-led-light-box------
# -----CREATOR-----
# --------normaltech/i-am-decals-share-your-story------
# -----CREATOR-----
# --------2019786209/of-writers-nights-and-open-mics------
# -----CREATOR-----
# --------192426477/blockchain-tech-news-and-information-brought-to-yo------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------1489473439/singulars-donner-du-sens-pour-rendre-unique------
# -----CREATOR-----
# --------1633272844/sportsastoldbyagirl------
# -----CREATOR-----
# --------marinaxstudios/parti-colour-huevember-2019------
# -----CREATOR-----
# --------fredlanthier/space-themed-enamel-pin-collection------
# -----CREATOR-----
# --------cincyacaibol/there-is-no-acai-bowl-food-truck-in-cincinnati------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------darrenwall/gamesmaster-the-oral-history------
# -----CREATOR-----
# --------autumnstayofficial/autumn-stay-rise-above------
# -----CREATOR-----
# --------106572506/i-love-black-history------
# -----CREATOR-----
# --------ageek/html-with-mom-20-making-the-web-accessible------
# -----CREATOR-----
# --------720005639/latelier-ki-and-co-projet-de-coworking-0------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------seafish-sandbab/seafood-sandbab------
# -----CREATOR-----
# --------1109325999/the-next-great-keystone-of-american-journalism------
# -----CREATOR-----
# --------1235183688/petes-passion-project------
# -----CREATOR-----
# --------trenorthdvm/what-the-f-k-is-this-really-vetmed------
# -----CREATOR-----
# --------karuna/letters-to-my-ten-year-old-self------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------justinmcroberts/justins-18th-musical-project------
# -----CREATOR-----
# --------slydersmith/slyder-smith-and-the-oblivion-kids-debut-album------
# -----CREATOR-----
# --------frenchyandthepunk/zen-ghost-the-new-album-by-frenchy-and-the-punk------
# -----CREATOR-----
# --------flavors/blanketpals-tm------
# -----CREATOR-----
# --------108366845/kickstarter-onboarding-teardown-supreme------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------567819193/novact------
# -----CREATOR-----
# --------2073861063/gorsline-news-media------
# -----CREATOR-----
# --------beepositive/colourful-christmas-cards-and-festive-goodies------
# -----CREATOR-----
# --------fashionbydiana/2020-fashion-calendar-by-diana-boch------
# -----CREATOR-----
# --------bmichaellogan/ghosts-of-japan-0------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------1708260474/la4u-a-new-phone-app-based-alternative-to-la-weekl------
# -----CREATOR-----
# --------1634798217/loveabq-social-media-campaign------
# -----CREATOR-----
# --------kawaiinepins/wizarding-wonders-vol-2------
# -----CREATOR-----
# --------226919544/the-painting-racehorse-a-documentary------
# -----CREATOR-----
# --------254673237/chipembele-film-project-0------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------xephyrforthalbum/xephyrs-forth-album------
# -----CREATOR-----
# --------564727717/sonic-alchemy-help-fund-the-recording-of-our-2nd-album------
# -----CREATOR-----
# --------psychicsunvinyl/psychic-sun-vinyl-record------
# -----CREATOR-----
# --------contagiouscourage/contagious-courage------
# -----CREATOR-----
# --------tanjarinekitchen/tanjarine-kitchen-needs-your-help------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------vansauwastacos/vansauwas-tacos-and-vegan-eats-caribbean-taco-trailer------
# -----CREATOR-----
# --------knyph-knaut/the-oaxacan-weaver-a-documentary------
# -----CREATOR-----
# --------1195082866/from-bedrooms-to-billions-the-playstation-revoluti------
# -----CREATOR-----
# --------atomscollision/pyrosclastic-flow-datoms-collision------
# -----CREATOR-----
# --------3d-origami-napkins/3d-origami-paper-napkins------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------1628947801/the-chicago-way-the-companion-book------
# -----CREATOR-----
# --------microcosmpublishing/unf-ck-your-anxiety------
# -----CREATOR-----
# --------purplelettepixiie/moon-family-hard-enamel-pins------
# -----CREATOR-----
# --------cabncakes/cookies-cakes-coffee-and-a-camper------
# -----CREATOR-----
# --------leechbugusc/leechbug-usc-games------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------chi-pie/chi-pie-chicago-style-pizza-on-wheels------
# -----CREATOR-----
# --------thebuffalosoldier/the-buffalo-soldier-food-truck-project------
# -----CREATOR-----
# --------arodz/just-enjoy-the-f-ing-ride-book------
# -----CREATOR-----
# --------dreamcreamco/lazy-days-spinning-hard-enamel-pins------
# -----CREATOR-----
# --------844238922/a-diamond-in-the-buff-the-lance-diamond-movie------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------1008136903/mobile-drive-in-movie-theater-built-with-a-food-tr------
# -----CREATOR-----
# --------2001768678/casabe-coffee-foodtruck-shop------
# -----CREATOR-----
# --------1904428802/born-to-play-the-barry-davis-story------
# -----CREATOR-----
# --------proteanman/building-vader------
# -----CREATOR-----
# --------reachlegal/reach-legal------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------890321722/health-and-fitness-all-your-basic-fitness-needs------
# -----CREATOR-----
# --------1811494792/kassahun-production------
# -----CREATOR-----
# --------giantsky/giant-skys-debut-album------
# -----CREATOR-----
# --------969220185/easytogo-sushi-healthy-freshfood-selfmade-products------
# -----CREATOR-----
# --------550796784/food-id------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------gregorylary/french-loaf-express------
# -----CREATOR-----
# --------tastes-like-more/tastes-like-more-serving-locally-sourced-delicious------
# -----CREATOR-----
# --------whatthefunk/what-the-funk------
# -----CREATOR-----
# --------1985696403/help-fuel-the-big-belly-kitchen------
# -----CREATOR-----
# --------1967506983/count-down------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------cobju9/debut-album-of-the-capeverdean-rock-band-cobju9------
# -----CREATOR-----
# --------sunhouseofficial/sun-house-ticket-to-fly------
# -----CREATOR-----
# --------lostmtns/this-aint-the-city-explorers-guide-to-the-blue-mountains------
# -----CREATOR-----
# --------theblock/the-block-texas-style-bbq-food-truck------
# -----CREATOR-----
# --------137213226/goat-sports-bar-food-truck-project-0------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------46224247/gordos-food-truck------
# -----CREATOR-----
# --------pyreusa/box-art-a-gaming-documentary------
# -----CREATOR-----
# --------367723613/help-senior-students-documentary-project------
# -----CREATOR-----
# --------reframe/reframe-finishing-funds------
# -----CREATOR-----
# --------excitethelight/twisted-illusion-temple-of-artifice-vinyl------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------forestandthesea/commuter-album-pre-sale------
# -----CREATOR-----
# --------leemunsmith/castrovalva-we-are-a-unit-deluxe-vinyl------
# -----CREATOR-----
# --------rozbruce/seven-reasons-why------
# -----CREATOR-----
# --------glowry/glowry-board-brings-out-the-genius-within-us------
# -----CREATOR-----
# --------alpoma/make-100-physics-atlas-1889------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------mariabenavides/a-summer-with-the-butterflies------
# -----CREATOR-----
# --------1686017362/badadaba-the-sound-of-travel-travel-gift-box------
# -----CREATOR-----
# --------15928743/expectant-0------
# -----CREATOR-----
# --------341356720/food-food-truck------
# -----CREATOR-----
# --------1979090260/rejino-barbeque------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------304401886/educational-plant-based-food-truck------
# -----CREATOR-----
# --------1027012346/fat-llama-grill-food-truck-and-catering------
# -----CREATOR-----
# --------vmmakespace/climate-heroes------
# -----CREATOR-----
# --------1951348237/human-weeds-documentary------
# -----CREATOR-----
# --------ultrasonic/ultra-sonic-hardcore-will-never-die-1997-oldskool-rave-album------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------michaelmood/starlight-3------
# -----CREATOR-----
# --------110952293/nox-houses------
# -----CREATOR-----
# --------billy-chester/the-wesn-samla-a-friction-folding-pocket-knife------
# -----CREATOR-----
# --------evybenita/mermaids-part-2------
# -----CREATOR-----
# --------307169713/loquacious-placemat-vol-1-a-reborn-literary-broads------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------cassidyminarik/chiane-from-far-rockaway------
# -----CREATOR-----
# --------inspirationscd/the-journey-home-album-by-sean-mcgee------
# -----CREATOR-----
# --------dewiikiwii/ghoulish-gals-enamel-pins------
# -----CREATOR-----
# --------divemaster300/the-divemaster-300-london-designed-adventure-inspired------
# -----CREATOR-----
# --------gracieux/secrecy-body-and-hip-bag-genuine-leather-bag-for-minimalists------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------1601514898/the-workout-session-part-2------
# -----CREATOR-----
# --------bupcake/the-eatens-family-spooky-enamel-pins------
# -----CREATOR-----
# --------moonbrewco/little-familiars------
# -----CREATOR-----
# --------ashleybrownfilms/life-on-mars-1------
# -----CREATOR-----
# --------tonightatdawn/from-jersey-with-love------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------612604676/save-the-peace-cross-documentary------
# -----CREATOR-----
# --------everydaymakai-coolio/the-coolio-a-lightweight-cooler-for-everyday-adventurers------
# -----CREATOR-----
# --------2141433675/river-vibe-music-fest------
# -----CREATOR-----
# --------452521412/jasmines-singing-career------
# -----CREATOR-----
# --------1140179356/the-whispers-and-natural-sounds-of-vt------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------1253099771/live-wild-documentary-film------
# -----CREATOR-----
# --------poiremolle/my-garden-deck-a-tarot-deck------
# -----CREATOR-----
# --------vesta-sleep/vesta-pillow------
# -----CREATOR-----
# --------woolandoak/the-mini-all-day-bag------
# -----CREATOR-----
# --------744767923/woman-publisher-embracing-two-counties-in-the-bubb------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------1329559177/door-county-socials-summer-blockbuster-digital-mag------
# -----CREATOR-----
# --------dancarterhempplastic/hemp-bio-degradable-plastic-food-cutlery------
# -----CREATOR-----
# --------778859891/extremity-magazine------
# -----CREATOR-----
# --------1248905651/vive-creole-magazine------
# -----CREATOR-----
# --------1612457457/blue-one-pink-one-a-publication-for-little-souls------
# -----CREATOR-----

# %% [markdown]
# # Saving Data
#
# ## Latest Iteration Ran Till: 2999, Local copy latest: 2000 to 2999

# %%
#SAVE LIST IN LOCAL FOR USE LATER. NAME FILE AS {from}_{to]_{story/risk}.json
creator_file_name = "/Users/ivankoh/Downloads/bt4222 data/2000_2999_creator" #CHANGE THIS
creator_file_name += ".json"

with open(creator_file_name, 'w') as f:
    # indent=2 is not needed but makes the file human-readable 
    # if the data is nested
    json.dump(creator_list, f, indent=2) 
    
# with open(story_file_name, 'r') as f:
#     story_subset = json.load(f)

# %%
print("creator:", len(creator_list))
# Out:
# creator: 1000

# %%
print("LATEST CALL DF ROW", "\n")
print(df_1.iloc[2000+len(creator_list)-1]['creator'])

print("LATEST CREATOR IN LIST", "\n")
print(creator_list[-1])
# Out:
# LATEST CALL DF ROW
#
# {"id":1612457457,"name":"ariel","is_registered":null,"is_email_verified":null,"chosen_currency":null,"is_superbacker":null,"avatar":{"thumb":"https://ksr-ugc.imgix.net/assets/006/470/577/81edbf612d8af940c96efa151d1b151f_original.jpg?ixlib=rb-4.0.2&w=40&h=40&fit=crop&v=1461390709&auto=format&frame=1&q=92&s=de27d7e7d2a9d8f415a6d0afad2e478c","small":"https://ksr-ugc.imgix.net/assets/006/470/577/81edbf612d8af940c96efa151d1b151f_original.jpg?ixlib=rb-4.0.2&w=80&h=80&fit=crop&v=1461390709&auto=format&frame=1&q=92&s=9471c81d1aaa58e587b318c996df239c","medium":"https://ksr-ugc.imgix.net/assets/006/470/577/81edbf612d8af940c96efa151d1b151f_original.jpg?ixlib=rb-4.0.2&w=160&h=160&fit=crop&v=1461390709&auto=format&frame=1&q=92&s=e3193fae5543754089bec8c2f534471e"},"urls":{"web":{"user":"https://www.kickstarter.com/profile/1612457457"},"api":{"user":"https://api.kickstarter.com/v1/users/1612457457?signature=1654837169.e02300e267b65ff540c8cba78b5c1cf921399e43"}}}
# LATEST CREATOR IN LIST
#
# {'id': 'UHJvamVjdC02MDUwMzMwMDk=', 'verifiedIdentity': None, 'creator': {'id': 'VXNlci0xNjEyNDU3NDU3', 'name': 'ariel', 'imageUrl': 'https://ksr-ugc.imgix.net/assets/006/470/577/81edbf612d8af940c96efa151d1b151f_original.jpg?ixlib=rb-4.0.2&w=160&h=160&fit=crop&v=1461390709&auto=format&frame=1&q=92&s=e3193fae5543754089bec8c2f534471e', 'url': 'https://www.kickstarter.com/profile/1612457457', 'lastLogin': 1543593339, 'biography': '', 'isFacebookConnected': True, 'allowsFollows': True, 'backingsCount': 0, 'location': {'displayableName': 'Austin, TX'}, 'launchedProjects': {'totalCount': 1}, 'websites': []}, 'collaborators': {'edges': []}}

# %%
s = requests.Session()

# %%
import requests
import json

url = "https://www.kickstarter.com/graph"

payload = json.dumps([
  {
    "variables": {
      "slug": "thehermetichermit/the-transient-mind-tarot"
    },
    "query": "query CreatorSection($slug: String!) {\n  me {\n    id\n    name\n  }\n  project(slug: $slug) {\n    id\n    verifiedIdentity\n    creator {\n      id\n      name\n      imageUrl(width: 100)\n      url\n      lastLogin\n      biography\n      isFacebookConnected\n      allowsFollows\n      backingsCount\n      location {\n        displayableName\n      }\n      launchedProjects {\n        totalCount\n      }\n      websites {\n        url\n        domain\n      }\n    }\n    collaborators {\n      edges {\n        node {\n          name\n          imageUrl(width: 200)\n          url\n        }\n        title\n      }\n    }\n  }\n}\n"
  }
])
headers = {
  'content-type': 'application/json',
  'x-csrf-token': 'fvjxrhwSYir6BG4U761oTRMXCYu4Ql88J4gTJaaXswCLm-qP6vzjo_vw1FdTY3VNpWEmuQb1MZH_JkJ-GuTPew',
  'user-agent': 'Mozilla/5.0 (Linux; U; Android 2.3.4; en-us; Kindle Fire Build/GINGERBREAD) AppleWebKit/533.1 (KHTML, like Gecko) Version/4.0 Mobile Safari/533.1',
  'cookie': '_ksr_session=XeMoOdlfAuvBg3vZkCPtR2KPkjnWtoE%2FGrwY68dNgE13OYvjkIxO0Eiaf4Oay2xzILiIHuLsmpCAH%2B9aBGT01%2B7gNDH6exw0dtPhWF5xVSYtZnJawqJNc8IUuF52GC%2FS7QHp1woosgy6PABnOt0X0ITzAvUEg8wwMmv5e1IBYNCmj8ZiCiUwlU2h08X3WX0lQSBSeatHjTEHV%2FgAjhqitXq1xvrNIY7MvvonoTMQat4mSbJKrOzGi74PUMwlhlgHz1oDCWy%2BqAiY%2BIQp9ft4c%2BK2ta8%3D--Rds4wbR2FagzmGoy--ZV4JbIYN8J%2FdS8uWWa5EQw%3D%3D'
}

response = requests.request("POST", url, headers=headers, data=payload)
print(response.status_code)
print(response.json())
a = response.json()
# Out:
# 200
# [{'data': {'me': None, 'project': {'id': 'UHJvamVjdC03NTY5NDA0MDI=', 'verifiedIdentity': 'Alexandra Eastman', 'creator': {'id': 'VXNlci0yMDE4MTg3NDcy', 'name': 'Alex E.', 'imageUrl': 'https://ksr-ugc.imgix.net/assets/036/415/186/53fbf1ce977b0312aead1aee65648ff2_original.jpg?ixlib=rb-4.0.2&w=160&h=160&fit=crop&v=1662144462&auto=format&frame=1&q=92&s=ec5c2c4451e85b255cfc03bca9f88b37', 'url': 'https://www.kickstarter.com/profile/thehermetichermit', 'lastLogin': 1664301753, 'biography': 'American living on Canadian soil. \r\nTarot reader for almost 15 years, graphic designer, lover of life.', 'isFacebookConnected': False, 'allowsFollows': True, 'backingsCount': 0, 'location': {'displayableName': 'Bucharest, Romania'}, 'launchedProjects': {'totalCount': 2}, 'websites': []}, 'collaborators': {'edges': []}}}}]

# %%
print(a[0]['data']['project'])
# Out:
# {'id': 'UHJvamVjdC03NTY5NDA0MDI=', 'verifiedIdentity': 'Alexandra Eastman', 'creator': {'id': 'VXNlci0yMDE4MTg3NDcy', 'name': 'Alex E.', 'imageUrl': 'https://ksr-ugc.imgix.net/assets/036/415/186/53fbf1ce977b0312aead1aee65648ff2_original.jpg?ixlib=rb-4.0.2&w=160&h=160&fit=crop&v=1662144462&auto=format&frame=1&q=92&s=ec5c2c4451e85b255cfc03bca9f88b37', 'url': 'https://www.kickstarter.com/profile/thehermetichermit', 'lastLogin': 1664301753, 'biography': 'American living on Canadian soil. \r\nTarot reader for almost 15 years, graphic designer, lover of life.', 'isFacebookConnected': False, 'allowsFollows': True, 'backingsCount': 0, 'location': {'displayableName': 'Bucharest, Romania'}, 'launchedProjects': {'totalCount': 2}, 'websites': []}, 'collaborators': {'edges': []}}
