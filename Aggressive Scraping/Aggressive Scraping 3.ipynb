# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import os 
import ast
import json
import time
from requests.exceptions import ConnectionError

# %% [markdown]
# https://stackoverflow.com/questions/62335537/scraping-text-from-kickstarter-projects-return-nothing

# %%
base = "/Users/ivankoh/Downloads/kickstarter data/"
filepaths = [base + f for f in os.listdir(base) if f.endswith('.csv')]
df = pd.concat(map(pd.read_csv, filepaths))
df_1 = df.drop_duplicates(subset=['id'])
df_1['main_url'] = df_1['urls'].apply(lambda x: eval(x)['web']['project'])
print(len(df))
print(len(df_1))
# Out:
# 392244
# 203510
# /var/folders/dq/33rpc0cx4f54t0vx2cdcgczr0000gn/T/ipykernel_42489/4110031066.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['main_url'] = df_1['urls'].apply(lambda x: eval(x)['web']['project'])

# %%
def get_slug(url):
    return re.search('/projects/(.*)\?', url).group(1)

# get the slug from the urls. the slug is the input to the GraphQL API call 
slugs = list(map(get_slug, df_1['main_url'].tolist()))
# while iterating through all projects, add the story and risk to these lists. At the end len of both list 
# should be the same as the len of the dataframe. if all good then add as columns to the dataframe df. 
creator_list = []

# %%
# instantiate a new Session 
s = requests.Session()

query = """
query Campaign($slug: String!) {
  project(slug: $slug) {
    risks
    story(assetWidth: 680)
  }
}"""

# PARAMS
counter = 0
# pause for 30 seconds every 5 iterations
for i in range(23511, 44022):
    slug = slugs[i]
    if counter == 5:
        print("TAKING A NAP ZZZ...")
        time.sleep(30)
        counter = 0
    counter += 1
    print(f"--------{slug}------")
    # POST request to GraphQL API situated in kickstarter domain 
    # response from POST request should contain the story and risks
    connect_try = 0
    not_found = True
    while connect_try < 30 and not_found:       
        try:
            r = s.post("https://www.kickstarter.com/graph",
                headers = {
                  'content-type': 'application/json',
                  'x-csrf-token': 'bL5nMRm5s147N8RxvNcth-E8NAOt3SprGYtvvKsVLnuZ3XwQ71cy1zrDfjIAGTCHV0obMRNqRMbBJT7nF2ZSAA',
                  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
                  'cookie': '_ksr_session=eus10UNK7iB%2FwIMXafXg5yJdYvRD7rHlR%2Ba1KEbUnB5EKTgQxNKEIqrp%2BIyjRC%2FNXw76u4Eki4AsiBom5M1LKNJKWCD65CBzeegWrk2%2FRV9Sht6dlOKplCATNdrmEIIa0Bt%2FKKGnT2m9ID1nTCduj73%2BdeJK663MNcbYWXBHkFyZJgUKh4JcCx3hL0UF2quVeBvfV45M0CNrT1j4DchvTlFBn%2BpE37ZaGldNz7BF0RAcCjIZrt%2FzNkxugCaFfWEPjxh9amOCvytIcdjxOaE68AAmHuU%3D--RPNmoWC%2FGnWTmsfw--9466UG%2Bqs2V%2F8B8zFtXUig%3D%3D'
                },
                json = {
                    "variables":{
                        "slug": slug
                    },
                    "query": "query CreatorSection($slug: String!) {\n  me {\n    id\n    name\n  }\n  project(slug: $slug) {\n    id\n    verifiedIdentity\n    creator {\n      id\n      name\n      imageUrl(width: 100)\n      url\n      lastLogin\n      biography\n      isFacebookConnected\n      allowsFollows\n      backingsCount\n      location {\n        displayableName\n      }\n      launchedProjects {\n        totalCount\n      }\n      websites {\n        url\n        domain\n      }\n    }\n    collaborators {\n      edges {\n        node {\n          name\n          imageUrl(width: 200)\n          url\n        }\n        title\n      }\n    }\n  }\n}\n"
                })
            not_found = False
        except ConnectionError:
            print("Connection Error")
            time.sleep(5)
            connect_try += 1
    try:
        result = r.json()
        print("-----CREATOR-----")
        creator_list.append(result['data']['project'])
    except:
        print(r)
        print("TAKING A BIG NAP ZZZ...")
        time.sleep(60*30)
        #try one more time
        r = s.post("https://www.kickstarter.com/graph",
                headers = {
                  'content-type': 'application/json',
                  'x-csrf-token': 'bL5nMRm5s147N8RxvNcth-E8NAOt3SprGYtvvKsVLnuZ3XwQ71cy1zrDfjIAGTCHV0obMRNqRMbBJT7nF2ZSAA',
                  'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:50.0) Gecko/20100101 Firefox/50.0',
                  'cookie': '_ksr_session=eus10UNK7iB%2FwIMXafXg5yJdYvRD7rHlR%2Ba1KEbUnB5EKTgQxNKEIqrp%2BIyjRC%2FNXw76u4Eki4AsiBom5M1LKNJKWCD65CBzeegWrk2%2FRV9Sht6dlOKplCATNdrmEIIa0Bt%2FKKGnT2m9ID1nTCduj73%2BdeJK663MNcbYWXBHkFyZJgUKh4JcCx3hL0UF2quVeBvfV45M0CNrT1j4DchvTlFBn%2BpE37ZaGldNz7BF0RAcCjIZrt%2FzNkxugCaFfWEPjxh9amOCvytIcdjxOaE68AAmHuU%3D--RPNmoWC%2FGnWTmsfw--9466UG%2Bqs2V%2F8B8zFtXUig%3D%3D'
                },
                json = {
                    "variables":{
                        "slug": slug
                    },
                    "query": "query CreatorSection($slug: String!) {\n  me {\n    id\n    name\n  }\n  project(slug: $slug) {\n    id\n    verifiedIdentity\n    creator {\n      id\n      name\n      imageUrl(width: 100)\n      url\n      lastLogin\n      biography\n      isFacebookConnected\n      allowsFollows\n      backingsCount\n      location {\n        displayableName\n      }\n      launchedProjects {\n        totalCount\n      }\n      websites {\n        url\n        domain\n      }\n    }\n    collaborators {\n      edges {\n        node {\n          name\n          imageUrl(width: 200)\n          url\n        }\n        title\n      }\n    }\n  }\n}\n"
                })
        try:
            result = r.json()
            print("-----CREATOR-----")
            creator_list.append(result['data']['project'])
        except:
            print("NAP DIDN't WORK", r)
            break
# Out:
# --------christopherdoll/doll-house-baked-goods------
# -----CREATOR-----
# --------ligetiquartet/songbooks-i-and-ii------
# -----CREATOR-----
# --------composerkirk/persephone-0------
# -----CREATOR-----
# --------youngminyou/youngmin-yous-first-official-album-release------
# -----CREATOR-----
# --------audentiaensemble/beethoven-cycle-dare-to-know------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------226727204/the-lost-children-a-novel------
# -----CREATOR-----
# --------57907789/the-empty-desert------
# -----CREATOR-----
# --------1743890303/salad-in-a-jar------
# -----CREATOR-----
# --------501930951/marisa-angela-fights-hunger------
# -----CREATOR-----
# --------1386477496/como-gopo-gourmet-popcorn-2-expand-we-need-equipme------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------852689639/jbryant-art------
# -----CREATOR-----
# --------192962040/modern-monk-brewery------
# -----CREATOR-----
# --------608283834/the-ring-master------
# -----CREATOR-----
# --------toothfairy/tooth-fairy------
# -----CREATOR-----
# --------radulescu/horatiu-radulescu-recording-of-the-complete-cello------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------hauntedblue/jazz-art-song-album-haunted-blue------
# -----CREATOR-----
# --------yerbury/naked-ruins------
# -----CREATOR-----
# --------jackiehummel/black-lives-matter-series------
# -----CREATOR-----
# --------ksvh/make-100-vivid-heart------
# -----CREATOR-----
# --------1805305299/secret-lives-of-our-pets-paint-peoples-loyal-compa------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------1549140596/michael-markowski-saxophone-quartet-commission------
# -----CREATOR-----
# --------1764367409/make-100-each-a-one-of-a-kind-t-shirt-art------
# -----CREATOR-----
# --------chunbumpark/i-want-to-sell-prints-of-original-paintings------
# -----CREATOR-----
# --------superlerty/eragon-fan-web-film------
# -----CREATOR-----
# --------1343998711/love-money-and-can-can-dancers------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------jarkoxart/start-with-full-time-painting------
# -----CREATOR-----
# --------hdaerials/images-by-halcyon-halcyonimages------
# -----CREATOR-----
# --------964811609/equipment-and-website-for-mentoring-photography-st------
# -----CREATOR-----
# --------kevinkeller/intermezzo-20th-anniversary-platinum-edition------
# -----CREATOR-----
# --------marie-pierre/extraction-lyrique-award-winning-abstract-photogra------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------jamukawaii/jamus-japanese-jam------
# -----CREATOR-----
# --------796294059/the-parisian-feature-film------
# -----CREATOR-----
# --------1259632038/back-by-tomorrow-zelda-inspired-short-film------
# -----CREATOR-----
# --------543907327/help-finace-marvel-and-dcs-first-film-crossover-ap------
# -----CREATOR-----
# --------146970554/help-ligghtgamings-youtube-channel------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------marioverolini/the-polyptychs-of-the-sense-of-life------
# -----CREATOR-----
# --------1935284329/mallory-0------
# -----CREATOR-----
# --------941561091/marcel-tyberg-reviving-music-lost-in-the-holocaust------
# -----CREATOR-----
# --------1091224254/heartfelled-the-tale-of-the-identity-stealer------
# -----CREATOR-----
# --------350711420/neverland-book-to-film------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------1037403017/monney-tools-young-adults-guide-to-financial-freed------
# -----CREATOR-----
# --------714490245/the-gambling-goose-that-avoided-the-noose------
# -----CREATOR-----
# --------1890340079/know-your-worth------
# -----CREATOR-----
# --------1898506942/the-ink-shadow------
# -----CREATOR-----
# --------1691237388/spread-recovery-awareness-to-schools-nationally------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------cornalesta/akoya-peal-now-then-and-forever------
# -----CREATOR-----
# --------lilacwonderland/strawbuddies-hard-enamel-pins------
# -----CREATOR-----
# --------eachronicles/lgbtq-customizable-enamel-pin-collection-flags-and-pronouns------
# -----CREATOR-----
# --------trentonmoore/retracing-america------
# -----CREATOR-----
# --------woco/woco-nurturing-operatic-talent-puccinis-gianni-sch------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------425766633/barkeddocumenting-the-worlds-oldest-biggest-trees------
# -----CREATOR-----
# --------651446565/independence-affect-artist-book------
# -----CREATOR-----
# --------1140582406/university-of-brighton-third-year-degree-show-fund------
# -----CREATOR-----
# --------1555462122/wet-plate-collodion-darkroom-north-dakota-photogra------
# -----CREATOR-----
# --------475642416/north-coast-500-polaroid-project------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------katiekatopera/dvoraks-love-songs-a-music-film-project-by-katie-k------
# -----CREATOR-----
# --------1780126761/florida-youth-orchestra------
# -----CREATOR-----
# --------hallsmusic/cisum-percussions-new-album-and-commission-project------
# -----CREATOR-----
# --------1269765406/the-second-virtual-conductor-album-project------
# -----CREATOR-----
# --------1002915109/sarah-chalfy-goes-on-record-a-cabaret-album------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------chocolona/flowermon-enamel-pins------
# -----CREATOR-----
# --------pikakree/blossom-cuties-cherry-blossom-hard-enamel-pins------
# -----CREATOR-----
# --------simonecarasco/jay-genius------
# -----CREATOR-----
# --------nickhoyt/a-space-novella-in-japanese------
# -----CREATOR-----
# --------thirdeditions/third-editions-the-ultimate-anime-library------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------182876984/unheard-of-poetry-bringing-experimental-poets-into------
# -----CREATOR-----
# --------1590925398/my-new-life-in-the-north------
# -----CREATOR-----
# --------503623222/family-sports-viewing------
# -----CREATOR-----
# --------2120487938/montana-bear-school------
# -----CREATOR-----
# --------foragersdaughter/seeking-glass------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------2044211488/hells-kitchen-hot-sauce-nyc------
# -----CREATOR-----
# --------543220928/lady-butchers-of-saucisson-we-can-do-it-with-your------
# -----CREATOR-----
# --------1991803764/sugarbox-sundries-custom-cakes-and-creative-confec------
# -----CREATOR-----
# --------riselle/filipino-street-food-enamel-pins------
# -----CREATOR-----
# --------geekandartsy/artifacts-of-the-forgotten-realms------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------papershredder/nostalgia-bots-a-hard-enamel-pin-set------
# -----CREATOR-----
# --------nanny-silvestre/translation-traduction-7-novels-fr-to-eng------
# -----CREATOR-----
# --------836662217/globally-recognized-second-language------
# -----CREATOR-----
# --------1464755039/translating-novel-kings-hope-the-deadly-poker-tour------
# -----CREATOR-----
# --------yelpers/active-love-oracle------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------hopskeller/hopskeller-brewing-company-community-beer-garden------
# -----CREATOR-----
# --------spooky-pin-set/a-spooky-acrylic-pin-collection------
# -----CREATOR-----
# --------1193981287/delicious-vanilla-products-delivered-in-time-for-c------
# -----CREATOR-----
# --------1203583454/hello-bbq-sauce------
# -----CREATOR-----
# --------1945102584/pickle-pipe-waterless-fermentation-airlock-for-mas------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------1878443655/crosstown-brewing-company------
# -----CREATOR-----
# --------automate-this/dead-tech-hard-enamel-pins------
# -----CREATOR-----
# --------erascapes/lacuna-revelation-audio-short------
# -----CREATOR-----
# --------throughthenight/through-the-night-2------
# -----CREATOR-----
# --------theseahouse/the-sea-house-0------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------zbunii/senshi-accessories------
# -----CREATOR-----
# --------1036702000/rainbow-collection-hard-enamel-pins------
# -----CREATOR-----
# --------alivemu/les-mckeowns-bay-city-rollers-the-last-tour-photobook------
# -----CREATOR-----
# --------emmaderieux--billaud/help-an-artist-to-recover-her-works-my-hard-drive-failled------
# -----CREATOR-----
# --------1108527245/get-brooklyn-wind-symphony-to-the-midwest-clinic------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------1702906333/two-chicks-beef-jerky------
# -----CREATOR-----
# --------917953900/the-puffman-movement-jakes-super-caramel-puff-corn------
# -----CREATOR-----
# --------1199487221/the-orders-are-piling-up------
# -----CREATOR-----
# --------2091942804/chi-cho-sauce-is-taking-over-the-world------
# -----CREATOR-----
# --------tiagosiewerdt/fog-of-chernobyl------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------voncello/if-you-like-rockin-strings-this-ones-for-you------
# -----CREATOR-----
# --------1246376845/williamsport-summer-strings-festival------
# -----CREATOR-----
# --------1599386810/we-travel-a-lot-the-vinyl-and-photo-edition------
# -----CREATOR-----
# --------1218131240/the-bloomin-bean------
# -----CREATOR-----
# --------honest5/honest5-food-and-treats-for-dogs------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------ourpopcornsquad/our-popcorn-squad------
# -----CREATOR-----
# --------1615934504/euripides-short-film------
# -----CREATOR-----
# --------715436319/the-cornerstone-chorale-spring-concert------
# -----CREATOR-----
# --------hodgdon/print-and-distribute-wrecked-fantasy-for-doublebas------
# -----CREATOR-----
# --------915441459/just-bobby-bob-weir-photographed-by-bob-minkin------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------caffecartel/caffe-cartel-coffee-for-the-people------
# -----CREATOR-----
# --------breakingbreadbakery/breaking-bread-bakery------
# -----CREATOR-----
# --------35078590/x-wing-pride-pin------
# -----CREATOR-----
# --------488251356/european-and-canadian-debut-in-a-career-in-opera------
# -----CREATOR-----
# --------880712721/pb-with-js------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------wmodes/a-secret-history-sacramento-river-expedition------
# -----CREATOR-----
# --------perlasdememoria/exposicion-perlas-de-memoria------
# -----CREATOR-----
# --------fistfulofbooks/lifes-a-ball-90s------
# -----CREATOR-----
# --------2025268053/wedding-things-marriot-1-95-96-found-video-digitiz------
# -----CREATOR-----
# --------abbeyandbear/cute-bear-bakery-sweatshirt------
# -----CREATOR-----
# TAKING A NAP ZZZ...
# --------livingwear/lw001-the-organic-mock-neck-tee-made-for-effortless-living------
# <Response [429]>
# TAKING A BIG NAP ZZZ...
# NAP DIDN't WORK <Response [429]>

# %% [markdown]
# # Saving Data
#
# ## Latest Iteration Ran Till: 2999, Local copy latest: 2000 to 2999

# %%
#SAVE LIST IN LOCAL FOR USE LATER. NAME FILE AS {from}_{to]_{story/risk}.json
creator_file_name = "/Users/ivankoh/Downloads/bt4222 data/2000_2999_creator" #CHANGE THIS
creator_file_name += ".json"

with open(creator_file_name, 'w') as f:
    # indent=2 is not needed but makes the file human-readable 
    # if the data is nested
    json.dump(creator_list, f, indent=2) 
    
# with open(story_file_name, 'r') as f:
#     story_subset = json.load(f)

# %%
print("creator:", len(creator_list))
# Out:
# creator: 1000

# %%
print("LATEST CALL DF ROW", "\n")
print(df_1.iloc[2000+len(creator_list)-1]['creator'])

print("LATEST CREATOR IN LIST", "\n")
print(creator_list[-1])
# Out:
# LATEST CALL DF ROW
#
# {"id":1612457457,"name":"ariel","is_registered":null,"is_email_verified":null,"chosen_currency":null,"is_superbacker":null,"avatar":{"thumb":"https://ksr-ugc.imgix.net/assets/006/470/577/81edbf612d8af940c96efa151d1b151f_original.jpg?ixlib=rb-4.0.2&w=40&h=40&fit=crop&v=1461390709&auto=format&frame=1&q=92&s=de27d7e7d2a9d8f415a6d0afad2e478c","small":"https://ksr-ugc.imgix.net/assets/006/470/577/81edbf612d8af940c96efa151d1b151f_original.jpg?ixlib=rb-4.0.2&w=80&h=80&fit=crop&v=1461390709&auto=format&frame=1&q=92&s=9471c81d1aaa58e587b318c996df239c","medium":"https://ksr-ugc.imgix.net/assets/006/470/577/81edbf612d8af940c96efa151d1b151f_original.jpg?ixlib=rb-4.0.2&w=160&h=160&fit=crop&v=1461390709&auto=format&frame=1&q=92&s=e3193fae5543754089bec8c2f534471e"},"urls":{"web":{"user":"https://www.kickstarter.com/profile/1612457457"},"api":{"user":"https://api.kickstarter.com/v1/users/1612457457?signature=1654837169.e02300e267b65ff540c8cba78b5c1cf921399e43"}}}
# LATEST CREATOR IN LIST
#
# {'id': 'UHJvamVjdC02MDUwMzMwMDk=', 'verifiedIdentity': None, 'creator': {'id': 'VXNlci0xNjEyNDU3NDU3', 'name': 'ariel', 'imageUrl': 'https://ksr-ugc.imgix.net/assets/006/470/577/81edbf612d8af940c96efa151d1b151f_original.jpg?ixlib=rb-4.0.2&w=160&h=160&fit=crop&v=1461390709&auto=format&frame=1&q=92&s=e3193fae5543754089bec8c2f534471e', 'url': 'https://www.kickstarter.com/profile/1612457457', 'lastLogin': 1543593339, 'biography': '', 'isFacebookConnected': True, 'allowsFollows': True, 'backingsCount': 0, 'location': {'displayableName': 'Austin, TX'}, 'launchedProjects': {'totalCount': 1}, 'websites': []}, 'collaborators': {'edges': []}}

# %%
s = requests.Session()

# %%
import requests
import json

url = "https://www.kickstarter.com/graph"

payload = json.dumps([
  {
    "variables": {
      "slug": "thehermetichermit/the-transient-mind-tarot"
    },
    "query": "query CreatorSection($slug: String!) {\n  me {\n    id\n    name\n  }\n  project(slug: $slug) {\n    id\n    verifiedIdentity\n    creator {\n      id\n      name\n      imageUrl(width: 100)\n      url\n      lastLogin\n      biography\n      isFacebookConnected\n      allowsFollows\n      backingsCount\n      location {\n        displayableName\n      }\n      launchedProjects {\n        totalCount\n      }\n      websites {\n        url\n        domain\n      }\n    }\n    collaborators {\n      edges {\n        node {\n          name\n          imageUrl(width: 200)\n          url\n        }\n        title\n      }\n    }\n  }\n}\n"
  }
])
headers = {
  'content-type': 'application/json',
  'x-csrf-token': 'fvjxrhwSYir6BG4U761oTRMXCYu4Ql88J4gTJaaXswCLm-qP6vzjo_vw1FdTY3VNpWEmuQb1MZH_JkJ-GuTPew',
  'user-agent': 'Mozilla/5.0 (Linux; U; Android 2.3.4; en-us; Kindle Fire Build/GINGERBREAD) AppleWebKit/533.1 (KHTML, like Gecko) Version/4.0 Mobile Safari/533.1',
  'cookie': '_ksr_session=XeMoOdlfAuvBg3vZkCPtR2KPkjnWtoE%2FGrwY68dNgE13OYvjkIxO0Eiaf4Oay2xzILiIHuLsmpCAH%2B9aBGT01%2B7gNDH6exw0dtPhWF5xVSYtZnJawqJNc8IUuF52GC%2FS7QHp1woosgy6PABnOt0X0ITzAvUEg8wwMmv5e1IBYNCmj8ZiCiUwlU2h08X3WX0lQSBSeatHjTEHV%2FgAjhqitXq1xvrNIY7MvvonoTMQat4mSbJKrOzGi74PUMwlhlgHz1oDCWy%2BqAiY%2BIQp9ft4c%2BK2ta8%3D--Rds4wbR2FagzmGoy--ZV4JbIYN8J%2FdS8uWWa5EQw%3D%3D'
}

response = requests.request("POST", url, headers=headers, data=payload)
print(response.status_code)
print(response.json())
a = response.json()
# Out:
# 200
# [{'data': {'me': None, 'project': {'id': 'UHJvamVjdC03NTY5NDA0MDI=', 'verifiedIdentity': 'Alexandra Eastman', 'creator': {'id': 'VXNlci0yMDE4MTg3NDcy', 'name': 'Alex E.', 'imageUrl': 'https://ksr-ugc.imgix.net/assets/036/415/186/53fbf1ce977b0312aead1aee65648ff2_original.jpg?ixlib=rb-4.0.2&w=160&h=160&fit=crop&v=1662144462&auto=format&frame=1&q=92&s=ec5c2c4451e85b255cfc03bca9f88b37', 'url': 'https://www.kickstarter.com/profile/thehermetichermit', 'lastLogin': 1664301753, 'biography': 'American living on Canadian soil. \r\nTarot reader for almost 15 years, graphic designer, lover of life.', 'isFacebookConnected': False, 'allowsFollows': True, 'backingsCount': 0, 'location': {'displayableName': 'Bucharest, Romania'}, 'launchedProjects': {'totalCount': 2}, 'websites': []}, 'collaborators': {'edges': []}}}}]

# %%
print(a[0]['data']['project'])
# Out:
# {'id': 'UHJvamVjdC03NTY5NDA0MDI=', 'verifiedIdentity': 'Alexandra Eastman', 'creator': {'id': 'VXNlci0yMDE4MTg3NDcy', 'name': 'Alex E.', 'imageUrl': 'https://ksr-ugc.imgix.net/assets/036/415/186/53fbf1ce977b0312aead1aee65648ff2_original.jpg?ixlib=rb-4.0.2&w=160&h=160&fit=crop&v=1662144462&auto=format&frame=1&q=92&s=ec5c2c4451e85b255cfc03bca9f88b37', 'url': 'https://www.kickstarter.com/profile/thehermetichermit', 'lastLogin': 1664301753, 'biography': 'American living on Canadian soil. \r\nTarot reader for almost 15 years, graphic designer, lover of life.', 'isFacebookConnected': False, 'allowsFollows': True, 'backingsCount': 0, 'location': {'displayableName': 'Bucharest, Romania'}, 'launchedProjects': {'totalCount': 2}, 'websites': []}, 'collaborators': {'edges': []}}
